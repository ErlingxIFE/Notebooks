# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
ghi_path = r'C:\Users\IFE12748\Downloads\Export_G8_G2_2022_05_01_2023_08_30.csv'

# %%
ghi_df =pd.read_csv(ghi_path, index_col=0, sep=';')
ghi_df.index = pd.to_datetime(ghi_df.index)

# %%
ghi_df.iloc[17200:17700,:].plot()
# Out:
# <Axes: xlabel='Timestamp'>
